# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoGurrola/Probabilidad-Y-Estadistica/blob/main/probabilidad_U4_Programa4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad y estadistica**
#
# **Grupo 3 Y**
#
# **Unidad 2**
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Diego Francisco Gurrola Terrones
#
# **Practica 4: probabilidad_U4_Programa4**

# %%
from scipy.stats import poisson

lam = 3
p_exact_2 = poisson.pmf(k=2, mu=lam)

print(f"P(exactamente 2 eventos en una hora) = {p_exact_2:.4f}")
# Out:
# P(exactamente 2 eventos en una hora) = 0.2240
