# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoGurrola/Probabilidad-Y-Estadistica/blob/main/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad y estadistica**
#
# **Grupo 2 Y**
#
# **Unidad 1**
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Diego Francisco Gurrola Terrones
#
# **Practica 3: Tabla de frecuencias y regla de Sturges.**

# %%
import random
edades = []
for i in range (100):
    numero_aleatorio = random.randint( 18, 70)
    edades.append(numero_aleatorio)
print(edades)
# Out:
# [40, 54, 34, 57, 43, 55, 69, 34, 35, 35, 61, 33, 69, 44, 21, 28, 49, 33, 25, 41, 51, 18, 62, 61, 59, 55, 28, 23, 52, 22, 23, 45, 51, 58, 52, 28, 62, 68, 23, 26, 60, 29, 47, 49, 48, 51, 52, 38, 19, 51, 31, 39, 25, 18, 53, 19, 36, 53, 57, 44, 65, 41, 62, 39, 30, 18, 20, 39, 64, 46, 67, 52, 20, 65, 30, 29, 55, 67, 49, 51, 57, 31, 30, 68, 45, 41, 41, 54, 62, 62, 48, 33, 66, 42, 51, 20, 42, 34, 43, 34]

# %%
df = pd.DataFrame(edades, columns=['edad'])
df.head()
# Out:
#    edad
# 0    40
# 1    54
# 2    34
# 3    57
# 4    43

# %%
tabla_frecuencias = df['edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("tabla de distrubucion de frecuencias:")
display(tabla_frecuencias)
# Out:
# tabla de distrubucion de frecuencias:
#     Edad  Frecuencia
# 7     18           3
# 30    19           2
# 14    20           3
# 33    21           1
# 35    22           1
# 8     23           3
# 28    25           2
# 38    26           1
# 10    28           3
# 23    29           2
# 13    30           3
# 31    31           2
# 11    33           3
# 4     34           4
# 15    35           2
# 41    36           1
# 40    38           1
# 5     39           3
# 32    40           1
# 2     41           4
# 21    42           2
# 19    43           2
# 16    44           2
# 26    45           2
# 43    46           1
# 39    47           1
# 25    48           2
# 6     49           3
# 0     51           6
# 3     52           4
# 24    53           2
# 18    54           2
# 12    55           3
# 9     57           3
# 36    58           1
# 34    59           1
# 37    60           1
# 20    61           2
# 1     62           5
# 42    64           1
# 29    65           2
# 44    66           1
# 22    67           2
# 27    68           2
# 17    69           2

# %%
tabla_frecuencias['frec relativa'] = tabla_frecuencias[ 'Frecuencia']/ 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  frec relativa
# 7     18           3           0.03
# 30    19           2           0.02
# 14    20           3           0.03
# 33    21           1           0.01
# 35    22           1           0.01
# 8     23           3           0.03
# 28    25           2           0.02
# 38    26           1           0.01
# 10    28           3           0.03
# 23    29           2           0.02
# 13    30           3           0.03
# 31    31           2           0.02
# 11    33           3           0.03
# 4     34           4           0.04
# 15    35           2           0.02
# 41    36           1           0.01
# 40    38           1           0.01
# 5     39           3           0.03
# 32    40           1           0.01
# 2     41           4           0.04
# 21    42           2           0.02
# 19    43           2           0.02
# 16    44           2           0.02
# 26    45           2           0.02
# 43    46           1           0.01
# 39    47           1           0.01
# 25    48           2           0.02
# 6     49           3           0.03
# 0     51           6           0.06
# 3     52           4           0.04
# 24    53           2           0.02
# 18    54           2           0.02
# 12    55           3           0.03
# 9     57           3           0.03
# 36    58           1           0.01
# 34    59           1           0.01
# 37    60           1           0.01
# 20    61           2           0.02
# 1     62           5           0.05
# 42    64           1           0.01
# 29    65           2           0.02
# 44    66           1           0.01
# 22    67           2           0.02
# 27    68           2           0.02
# 17    69           2           0.02

# %%
tabla_frecuencias['frec porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  frec relativa  frec porcentual
# 7     18           3           0.03              3.0
# 30    19           2           0.02              2.0
# 14    20           3           0.03              3.0
# 33    21           1           0.01              1.0
# 35    22           1           0.01              1.0
# 8     23           3           0.03              3.0
# 28    25           2           0.02              2.0
# 38    26           1           0.01              1.0
# 10    28           3           0.03              3.0
# 23    29           2           0.02              2.0
# 13    30           3           0.03              3.0
# 31    31           2           0.02              2.0
# 11    33           3           0.03              3.0
# 4     34           4           0.04              4.0
# 15    35           2           0.02              2.0
# 41    36           1           0.01              1.0
# 40    38           1           0.01              1.0
# 5     39           3           0.03              3.0
# 32    40           1           0.01              1.0
# 2     41           4           0.04              4.0
# 21    42           2           0.02              2.0
# 19    43           2           0.02              2.0
# 16    44           2           0.02              2.0
# 26    45           2           0.02              2.0
# 43    46           1           0.01              1.0
# 39    47           1           0.01              1.0
# 25    48           2           0.02              2.0
# 6     49           3           0.03              3.0
# 0     51           6           0.06              6.0
# 3     52           4           0.04              4.0
# 24    53           2           0.02              2.0
# 18    54           2           0.02              2.0
# 12    55           3           0.03              3.0
# 9     57           3           0.03              3.0
# 36    58           1           0.01              1.0
# 34    59           1           0.01              1.0
# 37    60           1           0.01              1.0
# 20    61           2           0.02              2.0
# 1     62           5           0.05              5.0
# 42    64           1           0.01              1.0
# 29    65           2           0.02              2.0
# 44    66           1           0.01              1.0
# 22    67           2           0.02              2.0
# 27    68           2           0.02              2.0
# 17    69           2           0.02              2.0

# %%
tabla_frecuencias['frec acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  frec relativa  frec porcentual  frec acumulada
# 7     18           3           0.03              3.0               3
# 30    19           2           0.02              2.0               5
# 14    20           3           0.03              3.0               8
# 33    21           1           0.01              1.0               9
# 35    22           1           0.01              1.0              10
# 8     23           3           0.03              3.0              13
# 28    25           2           0.02              2.0              15
# 38    26           1           0.01              1.0              16
# 10    28           3           0.03              3.0              19
# 23    29           2           0.02              2.0              21
# 13    30           3           0.03              3.0              24
# 31    31           2           0.02              2.0              26
# 11    33           3           0.03              3.0              29
# 4     34           4           0.04              4.0              33
# 15    35           2           0.02              2.0              35
# 41    36           1           0.01              1.0              36
# 40    38           1           0.01              1.0              37
# 5     39           3           0.03              3.0              40
# 32    40           1           0.01              1.0              41
# 2     41           4           0.04              4.0              45
# 21    42           2           0.02              2.0              47
# 19    43           2           0.02              2.0              49
# 16    44           2           0.02              2.0              51
# 26    45           2           0.02              2.0              53
# 43    46           1           0.01              1.0              54
# 39    47           1           0.01              1.0              55
# 25    48           2           0.02              2.0              57
# 6     49           3           0.03              3.0              60
# 0     51           6           0.06              6.0              66
# 3     52           4           0.04              4.0              70
# 24    53           2           0.02              2.0              72
# 18    54           2           0.02              2.0              74
# 12    55           3           0.03              3.0              77
# 9     57           3           0.03              3.0              80
# 36    58           1           0.01              1.0              81
# 34    59           1           0.01              1.0              82
# 37    60           1           0.01              1.0              83
# 20    61           2           0.02              2.0              85
# 1     62           5           0.05              5.0              90
# 42    64           1           0.01              1.0              91
# 29    65           2           0.02              2.0              93
# 44    66           1           0.01              1.0              94
# 22    67           2           0.02              2.0              96
# 27    68           2           0.02              2.0              98
# 17    69           2           0.02              2.0             100

# %%
import math
print(edades)
# Out:
# [40, 54, 34, 57, 43, 55, 69, 34, 35, 35, 61, 33, 69, 44, 21, 28, 49, 33, 25, 41, 51, 18, 62, 61, 59, 55, 28, 23, 52, 22, 23, 45, 51, 58, 52, 28, 62, 68, 23, 26, 60, 29, 47, 49, 48, 51, 52, 38, 19, 51, 31, 39, 25, 18, 53, 19, 36, 53, 57, 44, 65, 41, 62, 39, 30, 18, 20, 39, 64, 46, 67, 52, 20, 65, 30, 29, 55, 67, 49, 51, 57, 31, 30, 68, 45, 41, 41, 54, 62, 62, 48, 33, 66, 42, 51, 20, 42, 34, 43, 34]

# %%
df = pd.DataFrame({'edad':edades})
df
# Out:
#     edad
# 0     40
# 1     54
# 2     34
# 3     57
# 4     43
# ..   ...
# 95    20
# 96    42
# 97    34
# 98    43
# 99    34
#
# [100 rows x 1 columns]

# %%
n = len(edades)
K = int( 1 + math.log2(n))
print("Valor den =", n, " \nNúmero de intervalos =", K)
# Out:
# Valor den = 100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut( df['edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (47.143, 54.429]    19
# 1  (39.857, 47.143]    15
# 2  (17.948, 25.286]    15
# 3    (61.714, 69.0]    15
# 4  (32.571, 39.857]    14
# 5  (25.286, 32.571]    11
# 6  (54.429, 61.714]    11

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.948, 25.286]    15
# 5  (25.286, 32.571]    11
# 4  (32.571, 39.857]    14
# 1  (39.857, 47.143]    15
# 0  (47.143, 54.429]    19
# 6  (54.429, 61.714]    11
# 3    (61.714, 69.0]    15

# %%
tabla_frecuencia['Frec Relativa'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porcentual'] = tabla_frecuencia['Frec Relativa'] * 100
tabla_frecuencia['Frec rel Acumulada'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Acumulada'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Porcentual Acumulada'] = tabla_frecuencia['Frec Porcentual'].cumsum()
tabla_frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Relativa  Frec Porcentual  Frec Acumulada  \
# 2  (17.948, 25.286]    15           0.15             15.0              15
# 5  (25.286, 32.571]    11           0.11             11.0              26
# 4  (32.571, 39.857]    14           0.14             14.0              40
# 1  (39.857, 47.143]    15           0.15             15.0              55
# 0  (47.143, 54.429]    19           0.19             19.0              74
# 6  (54.429, 61.714]    11           0.11             11.0              85
# 3    (61.714, 69.0]    15           0.15             15.0             100
#
#    Frec Porcentual Acumulada  Frec rel Acumulada
# 2                       15.0                  15
# 5                       26.0                  26
# 4                       40.0                  40
# 1                       55.0                  55
# 0                       74.0                  74
# 6                       85.0                  85
# 3                      100.0                 100

# %%
plt.hist(edades, alpha = 0.5)
plt.title('histograma de edades basado en la funcion de matplotlib con valores estandar')
# Out:
# Text(0.5, 1.0, 'histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df['edad'], bins=K, alpha = 0.5)
plt.title('histograma de edades basado en la regla de sturges')
plt.xlabel('edades')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')
