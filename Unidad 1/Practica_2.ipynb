# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoGurrola/Probabilidad-Y-Estadistica/blob/main/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad Y Estadistica**
#
# **Grupo: 2 Y**
#
# **Unidad 1**
#
# **Practica 2: Máximo, mínimo, rango y dispersión de datos**
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Diego Francisco Gurrola Terrones

# %%
#Importar librerías y generar datos aleatorios para simular la producción en metros de
#tela de 2 fabricas
import random
import matplotlib.pyplot as plt
from statistics import*
fabrica1=[]
for i in range(100):
    numero_aleatorio =round( random. uniform (50,100), 2 )
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [56.88, 57.59, 86.22, 80.65, 75.45, 61.42, 77.12, 64.28, 95.83, 70.88, 80.9, 93.94, 68.9, 70.32, 96.03, 88.16, 93.79, 50.48, 71.6, 92.15, 99.14, 69.23, 66.06, 86.84, 60.62, 98.18, 81.48, 92.91, 70.59, 63.29, 56.92, 74.28, 50.83, 74.16, 98.98, 77.65, 99.55, 70.41, 70.82, 98.22, 58.92, 99.7, 92.44, 69.89, 55.7, 96.13, 91.79, 69.22, 51.89, 85.78, 58.57, 81.64, 82.9, 79.64, 62.49, 50.28, 54.98, 82.74, 96.8, 89.34, 94.51, 93.03, 55.39, 61.5, 92.5, 71.43, 85.31, 52.35, 80.05, 55.54, 78.32, 74.21, 83.03, 66.68, 85.6, 61.47, 90.02, 79.61, 61.66, 65.0, 76.15, 96.42, 83.35, 61.43, 69.01, 61.57, 76.49, 99.7, 68.29, 83.07, 76.73, 54.38, 62.26, 55.58, 94.04, 95.44, 87.92, 50.19, 96.35, 85.9]

# %%
fabrica2=[]
for i in range(100):
    numero_aleatorio =round( random. uniform (40,93), 2 )
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [68.85, 74.65, 68.67, 46.64, 92.87, 56.54, 47.7, 86.32, 65.52, 92.22, 42.28, 73.36, 74.37, 88.42, 67.45, 81.53, 81.25, 69.83, 88.92, 57.75, 81.77, 86.04, 75.75, 91.91, 41.71, 59.31, 71.68, 54.73, 60.81, 88.95, 79.52, 56.64, 85.3, 85.3, 72.04, 64.35, 42.37, 86.72, 75.45, 73.58, 43.3, 63.47, 62.57, 81.73, 89.67, 56.6, 42.45, 48.98, 86.47, 47.29, 90.63, 68.36, 77.4, 72.1, 84.12, 54.04, 65.08, 51.34, 65.9, 56.26, 43.74, 66.55, 52.15, 79.66, 64.36, 78.24, 90.7, 53.67, 77.64, 64.74, 43.44, 81.41, 46.04, 70.0, 68.89, 73.01, 51.11, 51.63, 69.8, 54.69, 84.36, 51.65, 84.21, 60.44, 60.34, 80.95, 48.05, 69.1, 70.48, 50.24, 55.87, 75.37, 49.06, 75.43, 75.96, 55.29, 56.26, 70.01, 63.37, 75.89]

# %%
#Estadísticas de la fábrica 1
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
print ( "Estadistica descriptiva de la Fabrica 1 \n", "Media =", media1,
"\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo = ", maximo1,
"\n Minimo =", minimo1, "\n Rango =", rango1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 76.2507
#  Mediana = 76.61
#  Moda = 99.7
#  Maximo =  99.7
#  Minimo = 50.19
#  Rango = 49.510000000000005

# %%
#Estadísticas de la fábrica 2
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo1 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
print( "Estadistica descriptiva de la Fabrica 2 \n", "Media =", media2,
"\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo = ", maximo2,
"\n Minimo =", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 67.6063
#  Mediana = 68.87
#  Moda = 85.3
#  Maximo =  92.87
#  Minimo = 41.71
#  Rango = 57.99

# %%
#Dispercion de datos
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.94741802337971

# %%
#Dispercion de datos 2
desviación_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 15.438744923344021

# %%
#Histograma fabrica 1
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
desviación_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
plt.figure(figsize = (8,6) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt. axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1 :.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f"Mediana={mediana1 :.2f}")
plt.axvline(moda1, color="y", linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color="black", linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2: .2f}')
plt.axvline(media1 + desviacion_estandar_fabrica2, color="black", linestyle='dashed',
            linewidth=2)
plt. xlabel('Valor')
plt.ylabel('Frecuencia' )
plt. title("Producción diaria de la fabrica 1")
plt. legend()
plt. show()
#fabrica 2
plt.figure(figsize = (8,6) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt. axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2 :.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f"Mediana={mediana2 :.2f}")
plt.axvline(moda2, color="y", linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color="black", linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2: .2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color="black", linestyle='dashed',
            linewidth=2)
plt. xlabel('Valor')
plt.ylabel('Frecuencia' )
plt. title("Producción diaria de la fabrica 2")
plt. legend()
plt. show()
# Out:
# 14.94741802337971
# 15.438744923344021

# %%
#Diagrama de densidad
import seaborn as sns
# La densidad gráfica es una forma de visualizar la distribución de datos en
# un intervalo o periodo de tiempo continuo.
# Se basa en un histograma que usa el suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones mas suaves al reducir el ruido.
# Una curva de densidad muestra la ubicación de la media y la mediana de una
# distribución.
sns.histplot( x = fabrica1, kde = True, kde_kws = {"bw_adjust": 0.5}, bins = 10 )
# Out:
# <Axes: ylabel='Count'>
