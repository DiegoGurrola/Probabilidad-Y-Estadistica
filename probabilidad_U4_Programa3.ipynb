# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoGurrola/Probabilidad-Y-Estadistica/blob/main/probabilidad_U4_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad y estadistica**
#
# **Grupo 3 Y**
#
# **Unidad 2**
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Diego Francisco Gurrola Terrones
#
# **Practica 3: probabilidad_U4_Programa3**

# %%
from scipy.stats import binom

n = 16
p = 0.83

p_todos_sufran = binom.pmf(k=0, n=n, p=p)

print(f"P(todos sufran la enfermedad) = {p_todos_sufran:.12e}")
# Out:
# P(todos sufran la enfermedad) = 4.866119187567e-13
