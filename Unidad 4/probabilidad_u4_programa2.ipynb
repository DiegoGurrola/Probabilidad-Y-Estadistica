# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoGurrola/Probabilidad-Y-Estadistica/blob/main/probabilidad_u4_programa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad y estadistica**
#
# **Grupo 2 Y**
#
# **Unidad 4**
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Diego Francisco Gurrola Terrones
#
# **Practica 2: distribucion binomial**

# %%
from scipy.stats import binom

n = 16
p = 0.83

p_ninguno_sufra = binom.pmf(k=16, n=n, p=p)

print(f"P(ninguno sufra la enfermedad) = {p_ninguno_sufra:.6f}")
# Out:
# P(ninguno sufra la enfermedad) = 0.050728
