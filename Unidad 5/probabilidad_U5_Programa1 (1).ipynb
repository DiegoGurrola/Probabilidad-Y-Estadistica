# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoGurrola/Probabilidad-Y-Estadistica/blob/main/probabilidad_U5_Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad y estadistica**
#
# **Grupo 3 Y**
#
# **Unidad 5**
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Diego Francisco Gurrola Terrones
#
# **Practica 1: probabilidad_U5_Programa1**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import tkinter as tk
from tkinter import filedialog
from google.colab import files # Import google.colab.files
import io # Import io for BytesIO

plt.close('all')

# Modified function to load file in Colab
def cargar_archivo():
    uploaded = files.upload()
    if uploaded:
        for filename in uploaded.keys():
            return io.BytesIO(uploaded[filename]) # Return a file-like object
    return None # Return None if no file was uploaded

def procesar_grupo(ruta, nombre):
    # Now, ruta will be a file-like object, so read_csv directly from it
    df = pd.read_csv(ruta)

    if "HorasEstudio" not in df.columns or "Calificacion" not in df.columns:
        print(f"ERROR: El archivo del {nombre} no contiene columnas válidas.\n")
        return

    print("\n==============================")
    print(f"RESULTADOS {nombre}")
    print("==============================")
    print("Descripción estadística del conjunto de datos:")
    print(df.describe())

    # Histograma
    plt.figure()
    plt.hist(df["Calificacion"], bins=10, edgecolor='black')
    plt.xlabel("Calificación")
    plt.ylabel("Frecuencia")
    plt.title(f"Histograma de Calificaciones - {nombre}")
    plt.show()

    X = df["HorasEstudio"].values.reshape(-1, 1)
    y = df["Calificacion"].values

    modelo = LinearRegression()
    modelo.fit(X, y)

    pendiente = modelo.coef_[0]
    intercepto = modelo.intercept_
    r2 = modelo.score(X, y)

    print(f"\nCoeficiente de determinación (R²): {r2:.4f}")
    print(f"Ecuación de la recta de regresión: y = {pendiente:.4f}x + {intercepto:.4f}")

    if pendiente > 0:
        interpretacion = "Existe una relación lineal positiva: a mayor número de horas de estudio, mayor calificación."
    elif pendiente < 0:
        interpretacion = "Existe una relación lineal negativa: a mayor número de horas de estudio, menor calificación."
    else:
        interpretacion = "No existe relación lineal entre las horas de estudio y las calificaciones."

    print("Interpretación:", interpretacion)
    print("======================================================\n")

    # Gráfica de dispersión y línea de regresión
    plt.figure()
    plt.scatter(df["HorasEstudio"], df["Calificacion"])
    plt.plot(df["HorasEstudio"], modelo.predict(X))
    plt.xlabel("Horas de Estudio")
    plt.ylabel("Calificación")
    plt.title(f"Regresión Lineal - {nombre}")
    plt.show()


# =======================
# PROCESAMIENTO DE LOS 3 GRUPOS
# =======================

print("Por favor, selecciona el archivo CSV para el GRUPO 1")
ruta1 = cargar_archivo()
if ruta1 is not None:
    procesar_grupo(ruta1, "GRUPO 1")

print("\nPor favor, selecciona el archivo CSV para el GRUPO 2")
ruta2 = cargar_archivo()
if ruta2 is not None:
    procesar_grupo(ruta2, "GRUPO 2")

print("\nPor favor, selecciona el archivo CSV para el GRUPO 3")
ruta3 = cargar_archivo()
if ruta3 is not None:
    procesar_grupo(ruta3, "GRUPO 3")
# Out:
# Por favor, selecciona el archivo CSV para el GRUPO 1
#      <input type="file" id="files-89dd008b-7b87-44ce-93b0-4f320bd949bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89dd008b-7b87-44ce-93b0-4f320bd949bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# Grupo 1
#
# Resultados numéricos
#
# n = 50
#
# Pendiente = –0.1061
#
# Intercepto = 85.3107
#
# Coeficiente de correlación r = –0.0571
#
# Coeficiente de determinación R² = 0.0032
#
# p-value (pendiente) = 0.6935
#
#
#
# 1. Interpretación del coeficiente de regresión
#
# La pendiente es –0.106, lo que indica que por cada hora adicional de estudio, la calificación esperada disminuye apenas 0.106 puntos.
#  Este valor es extremadamente pequeño y no tiene significado práctico.
#
# 2. Interpretación del coeficiente de correlación
#
# r = –0.057, lo cual representa una correlación negativa extremadamente débil.
#  En la práctica, esto significa que no existe relación lineal entre horas de estudio y calificaciones.
#
# 3. ¿El modelo es estadísticamente significativo?
#
# El p-value = 0.6935 (>0.05), por lo que la pendiente NO es significativa.
#  Conclusión: No hay evidencia estadística de relación lineal entre las variables.
#
# 4. Confiabilidad del modelo para predecir
#
# R² = 0.003, lo que significa que solo el 0.3% (prácticamente 0%) de la variabilidad de la calificación se explica por las horas estudiadas.
#  Este modelo no sirve para predecir calificaciones.
#
# Conclusión del Grupo 1
#
# No existe relación lineal entre el tiempo de estudio y el rendimiento académico. Las calificaciones parecen depender de otros factores no incluidos en el modelo.

# %% [markdown]
# Grupo 2
#
# Resultados numéricos
#
# n = 50
#
# Pendiente = 4.2227
#
# Intercepto = 15.3075
#
# r = 0.8620
#
# R² = 0.7430
#
# p-value = 9.07 × 10⁻¹⁶
#
#
#
# 1. Interpretación del coeficiente de regresión
#
# La pendiente = 4.22 significa que por cada hora adicional de estudio, la calificación aumenta 4.22 puntos en promedio.
#  Esto es un cambio grande y significativo.
#
# 2. Interpretación del coeficiente de correlación
#
# r = 0.862, lo cual indica una correlación positiva fuerte.
#  Mientras más estudian los estudiantes, más alta es su calificación.
#
# 3. ¿El modelo es estadísticamente significativo?
#
# p-value = 9×10⁻¹⁶ (<0.05)
#  El modelo es altamente significativo.
#  La relación es clara y no se debe al azar.
#
# 4. Confiabilidad del modelo para predecir
#
# R² = 0.743, por lo que el 74.3% de la variación de las calificaciones se explica por las horas de estudio.
#  El modelo es muy confiable para predicción.
#
# Conclusión del Grupo 2
#
# Existe una relación lineal fuerte, positiva y estadísticamente significativa.
#  El tiempo de estudio es un excelente predictor del rendimiento académico.

# %% [markdown]
# Grupo 3
#
# Resultados numéricos
#
# n = 50
#
# Pendiente = 5.2857
#
# Intercepto = 0.1080
#
# r = 0.9422
#
# R² = 0.8878
#
# p-value = 1.93 × 10⁻²⁴
#
#
#
# 1. Interpretación del coeficiente de regresión
#
# La pendiente = 5.28 indica que por cada hora adicional de estudio, la calificación aumenta 5.28 puntos.
#  Es un efecto muy grande.
#
# 2. Interpretación del coeficiente de correlación
#
# r = 0.942, lo que indica una correlación positiva extremadamente fuerte.
#  Las calificaciones aumentan consistentemente con las horas de estudio.
#
# 3. ¿El modelo es estadísticamente significativo?
#
# p-value = 1.93×10⁻²⁴ significancia extremadamente alta.
#  La relación lineal está totalmente demostrada.
#
# 4. Confiabilidad del modelo para predecir
#
# R² = 0.8878, lo que significa que el 88.7% de la variación de la calificación está explicada por el tiempo de estudio.
#  El modelo es altamente confiable y preciso para predecir.
#
# Conclusión del Grupo 3
#
# Existe una relación lineal muy fuerte y muy significativa entre el tiempo de estudio y el rendimiento académico.
#  El tiempo de estudio explica casi todo el desempeño final.

# %% [markdown]
# Conclusion general
#
# El análisis de regresión lineal simple aplicado a los tres grupos permitió evaluar la relación estadística entre las horas de estudio y el rendimiento académico. Los resultados muestran que dicha relación no es homogénea entre los grupos. En el Grupo 1 se obtuvo un coeficiente de determinación prácticamente nulo, lo que indica que la variabilidad en las calificaciones no puede explicarse mediante las horas de estudio. La pendiente negativa del modelo sugiere una tendencia inversa, aunque su magnitud es tan pequeña que carece de relevancia estadística. En consecuencia, el modelo de regresión lineal no resulta significativo para este grupo y no es adecuado para realizar inferencias ni predicciones.
#
# En contraste, el Grupo 2 presentó un coeficiente de determinación elevado, lo cual evidencia una relación lineal positiva y considerable entre las variables analizadas. En este grupo, las horas de estudio explican una proporción importante de la variación observada en las calificaciones, y la pendiente positiva del modelo indica que un incremento en el tiempo de estudio se asocia con un aumento en el rendimiento académico. Por tanto, el modelo de regresión lineal es estadísticamente sólido y funcional para estimar calificaciones dentro de este conjunto.
#
# El Grupo 3 mostró el coeficiente de determinación más alto de los tres, lo que revela una relación lineal muy fuerte entre el tiempo dedicado al estudio y las calificaciones finales. En este caso, la variabilidad en el rendimiento académico se explica ampliamente por la variable horas de estudio, por lo que el modelo de regresión resulta altamente significativo. La magnitud de la pendiente confirma una asociación positiva robusta y una capacidad predictiva considerable.
#
# En términos generales, se concluye que la relación entre horas de estudio y calificación depende del comportamiento específico de cada grupo. Mientras que en los grupos 2 y 3 el modelo de regresión lineal es adecuado, estadísticamente significativo y útil para fines predictivos, en el grupo 1 el modelo no describe adecuadamente los datos. Esto demuestra que la regresión lineal simple, aunque es una herramienta poderosa, solo es apropiada cuando la correlación entre las variables es suficientemente fuerte y consistente.
